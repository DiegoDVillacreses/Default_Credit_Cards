# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.core.metrics import make_scorer

import numpy as np
import pandas as pd

from sklearn.metrics import f1_score

pd.set_option('display.max_columns', 500)

# %%
df = pd.read_excel('../data/default of credit card clients.xls', skiprows=1)

# %%
# renaming the target variable
df.rename(columns={"default payment next month": "target"}, inplace=True)

# dropping ID
df.drop(columns='ID', inplace=True)

# Changing numeric encoding to labels
df['SEX'].replace([1, 2], ['Male', 'Female'], inplace=True)

df['MARRIAGE'].replace([1, 2, 3, 0], ['Married', 'Single', 'Other', 'Other'],
                       inplace=True)

df['EDUCATION'].replace([1, 2, 3, 4, 0, 5, 6], 
    ['GraduateSchool', 'University', 'HighSchool', 'Other', 'Other', 'Other','Other'],
                        inplace=True)

# %%
print("Distribution of the target variable - full data:\n",
      df["target"].value_counts(normalize=True),
      sep='')
# Out:
# Distribution of the target variable - full data:
# target
# 0    0.7788
# 1    0.2212
# Name: proportion, dtype: float64

# %%
def bank_profit(y_true, y_pred,alpha = 1/3):
    #earnings = alpha*true_negative - (1-alpha)*false_negative
    
    true_positive = sum(y_pred[y_pred==y_true] ==1)
    true_negative = sum(y_pred[y_pred==y_true] ==0)
    false_positive = sum(y_pred[y_pred!=y_true] ==1)
    false_negative = sum(y_pred[y_pred!=y_true] ==0)
    
    profit = (alpha*true_negative - (1-alpha)*false_negative)/(true_negative + false_negative)
    return profit


f1_ag = make_scorer(name="f1_binary", 
                    score_func=f1_score, 
                    average = "binary",
                    greater_is_better=True,
                    optimum = 1)

bank_profit_ag = make_scorer(name="bank_profit", 
                    score_func=bank_profit, 
                    greater_is_better=True)

# %%
minutes = 60
hours = 2

label = "target"
predictor_ag = TabularPredictor(label=label, eval_metric = bank_profit_ag)
predictor_ag.fit(df,
     presets='best_quality', #medium_quality, good_quality, best_quality
     time_limit = 60*minutes*hours, # in seconds
     num_gpus=1
     )

# %%
print("AutoGluon infers problem type is:", predictor_ag.problem_type)
print("AutoGluon identified the following types of features:")
print(predictor_ag.feature_metadata)
# Out:
# AutoGluon infers problem type is: binary
# AutoGluon identified the following types of features:
# ('category', [])  :  2 | ['EDUCATION', 'MARRIAGE']
# ('int', [])       : 20 | ['LIMIT_BAL', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', ...]
# ('int', ['bool']) :  1 | ['SEX']

# %%
predictor_ag.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                           model  score_val  eval_metric  pred_time_val     fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0     NeuralNetTorch_r79_BAG_L2   0.187523  bank_profit      17.152004  3825.446359                0.872996         285.182202            2       True         43
# 1           WeightedEnsemble_L3   0.187523  bank_profit      17.236003  3866.274917                0.083999          40.828557            3       True         47
# 2         NeuralNetTorch_BAG_L2   0.186627  bank_profit      17.033011  3810.412966                0.754003         270.148809            2       True         40
# 3           WeightedEnsemble_L2   0.183815  bank_profit       1.567027  1403.388195                0.084002          40.671755            2       True         30
# 4     NeuralNetTorch_r79_BAG_L1   0.183759  bank_profit       0.506002   442.649470                0.506002         442.649470            1       True         15
# 5     NeuralNetTorch_r22_BAG_L1   0.182422  bank_profit       0.590014   653.766883                0.590014         653.766883            1       True         20
# 6         NeuralNetTorch_BAG_L1   0.181562  bank_profit       0.387009   266.300086                0.387009         266.300086            1       True         12
# 7        NeuralNetFastAI_BAG_L2   0.177026  bank_profit      16.923208  3834.723192                0.644201         294.459035            2       True         38
# 8                XGBoost_BAG_L2   0.176568  bank_profit      16.499010  3552.966330                0.220002          12.702173            2       True         39
# 9               LightGBM_BAG_L2   0.176529  bank_profit      16.401986  3553.402263                0.122978          13.138106            2       True         32
# 10        ExtraTreesGini_BAG_L2   0.176413  bank_profit      18.087841  3543.118220                1.808833           2.854063            2       True         36
# 11              LightGBM_BAG_L1   0.176243  bank_profit       0.117958    10.707070                0.117958          10.707070            1       True          4
# 12              CatBoost_BAG_L2   0.176201  bank_profit      16.369034  3662.843996                0.090026         122.579839            2       True         35
# 13        ExtraTreesEntr_BAG_L2   0.176193  bank_profit      18.069758  3543.138093                1.790751           2.873936            2       True         37
# 14         LightGBMLarge_BAG_L2   0.176121  bank_profit      16.440022  3566.990207                0.161015          26.726049            2       True         41
# 15      RandomForestGini_BAG_L2   0.176119  bank_profit      18.005277  3555.672645                1.726269          15.408487            2       True         33
# 16      RandomForestEntr_BAG_L2   0.176112  bank_profit      17.959388  3557.135320                1.680380          16.871163            2       True         34
# 17         LightGBM_r131_BAG_L2   0.176066  bank_profit      16.470032  3564.558893                0.191024          24.294736            2       True         44
# 18               XGBoost_BAG_L1   0.175847  bank_profit       0.148005    12.478535                0.148005          12.478535            1       True         11
# 19            LightGBMXT_BAG_L2   0.175836  bank_profit      16.407953  3552.864581                0.128945          12.600423            2       True         31
# 20         CatBoost_r177_BAG_L2   0.175646  bank_profit      16.365984  3571.610428                0.086976          31.346271            2       True         42
# 21         LightGBMLarge_BAG_L1   0.175576  bank_profit       0.147994    18.219498                0.147994          18.219498            1       True         13
# 22        ExtraTrees_r42_BAG_L1   0.175354  bank_profit       1.434814     3.760165                1.434814           3.760165            1       True         22
# 23            LightGBMXT_BAG_L1   0.175325  bank_profit       0.109985     9.525662                0.109985           9.525662            1       True          3
# 24  NeuralNetFastAI_r191_BAG_L2   0.175305  bank_profit      17.164405  4093.882150                0.885397         553.617993            2       True         45
# 25           CatBoost_r9_BAG_L2   0.174892  bank_profit      16.386991  3579.092603                0.107983          38.828445            2       True         46
# 26         LightGBM_r131_BAG_L1   0.174757  bank_profit       0.203992    22.003094                0.203992          22.003094            1       True         16
# 27              CatBoost_BAG_L1   0.174616  bank_profit       0.079517   175.067956                0.079517         175.067956            1       True          7
# 28         CatBoost_r177_BAG_L1   0.174574  bank_profit       0.071978    28.312995                0.071978          28.312995            1       True         14
# 29      RandomForestGini_BAG_L1   0.174516  bank_profit       1.378175     6.041173                1.378175           6.041173            1       True          5
# 30        ExtraTreesGini_BAG_L1   0.174485  bank_profit       1.540983     2.137664                1.540983           2.137664            1       True          8
# 31           CatBoost_r9_BAG_L1   0.174444  bank_profit       0.098041   277.826541                0.098041         277.826541            1       True         18
# 32           XGBoost_r33_BAG_L1   0.174416  bank_profit       0.188013    24.517957                0.188013          24.517957            1       True         21
# 33     RandomForest_r195_BAG_L1   0.174391  bank_profit       1.373831    22.260263                1.373831          22.260263            1       True         26
# 34          LightGBM_r96_BAG_L1   0.174362  bank_profit       0.233994    29.609270                0.233994          29.609270            1       True         19
# 35         LightGBM_r188_BAG_L1   0.174349  bank_profit       0.145957    15.680303                0.145957          15.680303            1       True         27
# 36           XGBoost_r89_BAG_L1   0.174250  bank_profit       0.147001     4.477988                0.147001           4.477988            1       True         29
# 37      RandomForestEntr_BAG_L1   0.174233  bank_profit       1.354037     6.961488                1.354037           6.961488            1       True          6
# 38         CatBoost_r137_BAG_L1   0.174157  bank_profit       0.078991   214.476740                0.078991         214.476740            1       True         23
# 39          CatBoost_r13_BAG_L1   0.173803  bank_profit       0.079004   114.336690                0.079004         114.336690            1       True         25
# 40  NeuralNetFastAI_r145_BAG_L1   0.173750  bank_profit       1.183944    57.196902                1.183944          57.196902            1       True         28
# 41  NeuralNetFastAI_r102_BAG_L1   0.173596  bank_profit       0.221997    79.913653                0.221997          79.913653            1       True         24
# 42        ExtraTreesEntr_BAG_L1   0.173448  bank_profit       1.520994     2.115001                1.520994           2.115001            1       True          9
# 43       NeuralNetFastAI_BAG_L1   0.171826  bank_profit       0.592997   297.055731                0.592997         297.055731            1       True         10
# 44  NeuralNetFastAI_r191_BAG_L1   0.171244  bank_profit       0.856971   742.802384                0.856971         742.802384            1       True         17
# 45        KNeighborsDist_BAG_L1   0.133258  bank_profit       0.726818     0.032984                0.726818           0.032984            1       True          2
# 46        KNeighborsUnif_BAG_L1   0.132437  bank_profit       0.759992     0.030011                0.759992           0.030011            1       True          1
# Number of models trained: 47
# Types of models trained:
# {'StackerEnsembleModel_CatBoost', 'StackerEnsembleModel_TabularNeuralNetTorch', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_XT', 'StackerEnsembleModel_NNFastAiTabular', 'StackerEnsembleModel_XGBoost', 'WeightedEnsembleModel', 'StackerEnsembleModel_KNN', 'StackerEnsembleModel_LGB'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])  :  2 | ['EDUCATION', 'MARRIAGE']
# ('int', [])       : 20 | ['LIMIT_BAL', 'AGE', 'PAY_0', 'PAY_2', 'PAY_3', ...]
# ('int', ['bool']) :  1 | ['SEX']
# *** End of fit() summary ***
# c:\Users\Diego\miniconda3\envs\ag_gpu\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')
# {'model_types': {'KNeighborsUnif_BAG_L1': 'StackerEnsembleModel_KNN',
#   'KNeighborsDist_BAG_L1': 'StackerEnsembleModel_KNN',
#   'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L1': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L1': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L1': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'LightGBM_r96_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetTorch_r22_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'XGBoost_r33_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'ExtraTrees_r42_BAG_L1': 'StackerEnsembleModel_XT',
#   'CatBoost_r137_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetFastAI_r102_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r13_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'RandomForest_r195_BAG_L1': 'StackerEnsembleModel_RF',
#   'LightGBM_r188_BAG_L1': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r145_BAG_L1': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_r89_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestGini_BAG_L2': 'StackerEnsembleModel_RF',
#   'RandomForestEntr_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesGini_BAG_L2': 'StackerEnsembleModel_XT',
#   'ExtraTreesEntr_BAG_L2': 'StackerEnsembleModel_XT',
#   'NeuralNetFastAI_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'CatBoost_r177_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'NeuralNetTorch_r79_BAG_L2': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBM_r131_BAG_L2': 'StackerEnsembleModel_LGB',
#   'NeuralNetFastAI_r191_BAG_L2': 'StackerEnsembleModel_NNFastAiTabular',
#   'CatBoost_r9_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'KNeighborsUnif_BAG_L1': 0.13243747667039937,
#   'KNeighborsDist_BAG_L1': 0.1332582582582582,
#   'LightGBMXT_BAG_L1': 0.17532475745961873,
#   'LightGBM_BAG_L1': 0.17624259005927953,
#   'RandomForestGini_BAG_L1': 0.17451587028761315,
#   'RandomForestEntr_BAG_L1': 0.174232878978784,
#   'CatBoost_BAG_L1': 0.17461641515634083,
#   'ExtraTreesGini_BAG_L1': 0.1744852500031912,
#   'ExtraTreesEntr_BAG_L1': 0.1734480560866794,
#   'NeuralNetFastAI_BAG_L1': 0.1718255761409851,
#   'XGBoost_BAG_L1': 0.17584732320732926,
#   'NeuralNetTorch_BAG_L1': 0.18156221616712076,
#   'LightGBMLarge_BAG_L1': 0.1755764801174475,
#   'CatBoost_r177_BAG_L1': 0.17457427845412823,
#   'NeuralNetTorch_r79_BAG_L1': 0.18375868258799657,
#   'LightGBM_r131_BAG_L1': 0.1747565457921261,
#   'NeuralNetFastAI_r191_BAG_L1': 0.17124428580374473,
#   'CatBoost_r9_BAG_L1': 0.17444419151680704,
#   'LightGBM_r96_BAG_L1': 0.1743620822443594,
#   'NeuralNetTorch_r22_BAG_L1': 0.1824218136099324,
#   'XGBoost_r33_BAG_L1': 0.17441625646850936,
#   'ExtraTrees_r42_BAG_L1': 0.17535375246283358,
#   'CatBoost_r137_BAG_L1': 0.17415709030227178,
#   'NeuralNetFastAI_r102_BAG_L1': 0.17359641165205117,
#   'CatBoost_r13_BAG_L1': 0.17380320828596688,
#   'RandomForest_r195_BAG_L1': 0.17439141268928504,
#   'LightGBM_r188_BAG_L1': 0.17434925448572147,
#   'NeuralNetFastAI_r145_BAG_L1': 0.17374953945445995,
#   'XGBoost_r89_BAG_L1': 0.17425014789361726,
#   'WeightedEnsemble_L2': 0.18381520933317722,
#   'LightGBMXT_BAG_L2': 0.17583598927505434,
#   'LightGBM_BAG_L2': 0.17652949975913387,
#   'RandomForestGini_BAG_L2': 0.1761190993808561,
#   'RandomForestEntr_BAG_L2': 0.1761121267519805,
#   'CatBoost_BAG_L2': 0.1762007931379629,
#   'ExtraTreesGini_BAG_L2': 0.17641306970424267,
#   'ExtraTreesEntr_BAG_L2': 0.17619319262217148,
#   'NeuralNetFastAI_BAG_L2': 0.1770260639380981,
#   'XGBoost_BAG_L2': 0.17656753124920765,
#   'NeuralNetTorch_BAG_L2': 0.18662662820867407,
#   'LightGBMLarge_BAG_L2': 0.17612144732336488,
#   'CatBoost_r177_BAG_L2': 0.17564627915212222,
#   'NeuralNetTorch_r79_BAG_L2': 0.1875230566534914,
#   'LightGBM_r131_BAG_L2': 0.17606578115117014,
#   'NeuralNetFastAI_r191_BAG_L2': 0.17530460774628262,
#   'CatBoost_r9_BAG_L2': 0.17489157784268353,
#   'WeightedEnsemble_L3': 0.1875230566534914},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'KNeighborsUnif_BAG_L1': ['KNeighborsUnif_BAG_L1'],
#   'KNeighborsDist_BAG_L1': ['KNeighborsDist_BAG_L1'],
#   'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestGini_BAG_L1': ['RandomForestGini_BAG_L1'],
#   'RandomForestEntr_BAG_L1': ['RandomForestEntr_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesGini_BAG_L1': ['ExtraTreesGini_BAG_L1'],
#   'ExtraTreesEntr_BAG_L1': ['ExtraTreesEntr_BAG_L1'],
#   'NeuralNetFastAI_BAG_L1': ['NeuralNetFastAI_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'CatBoost_r177_BAG_L1': ['CatBoost_r177_BAG_L1'],
#   'NeuralNetTorch_r79_BAG_L1': ['NeuralNetTorch_r79_BAG_L1'],
#   'LightGBM_r131_BAG_L1': ['LightGBM_r131_BAG_L1'],
#   'NeuralNetFastAI_r191_BAG_L1': ['NeuralNetFastAI_r191_BAG_L1'],
#   'CatBoost_r9_BAG_L1': ['CatBoost_r9_BAG_L1'],
#   'LightGBM_r96_BAG_L1': ['LightGBM_r96_BAG_L1'],
#   'NeuralNetTorch_r22_BAG_L1': ['NeuralNetTorch_r22_BAG_L1'],
#   'XGBoost_r33_BAG_L1': ['XGBoost_r33_BAG_L1'],
#   'ExtraTrees_r42_BAG_L1': ['ExtraTrees_r42_BAG_L1'],
#   'CatBoost_r137_BAG_L1': ['CatBoost_r137_BAG_L1'],
#   'NeuralNetFastAI_r102_BAG_L1': ['NeuralNetFastAI_r102_BAG_L1'],
#   'CatBoost_r13_BAG_L1': ['CatBoost_r13_BAG_L1'],
#   'RandomForest_r195_BAG_L1': ['RandomForest_r195_BAG_L1'],
#   'LightGBM_r188_BAG_L1': ['LightGBM_r188_BAG_L1'],
#   'NeuralNetFastAI_r145_BAG_L1': ['NeuralNetFastAI_r145_BAG_L1'],
#   'XGBoost_r89_BAG_L1': ['XGBoost_r89_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestGini_BAG_L2': ['RandomForestGini_BAG_L2'],
#   'RandomForestEntr_BAG_L2': ['RandomForestEntr_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesGini_BAG_L2': ['ExtraTreesGini_BAG_L2'],
#   'ExtraTreesEntr_BAG_L2': ['ExtraTreesEntr_BAG_L2'],
#   'NeuralNetFastAI_BAG_L2': ['NeuralNetFastAI_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'NeuralNetTorch_BAG_L2': ['NeuralNetTorch_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'CatBoost_r177_BAG_L2': ['CatBoost_r177_BAG_L2'],
#   'NeuralNetTorch_r79_BAG_L2': ['NeuralNetTorch_r79_BAG_L2'],
#   'LightGBM_r131_BAG_L2': ['LightGBM_r131_BAG_L2'],
#   'NeuralNetFastAI_r191_BAG_L2': ['NeuralNetFastAI_r191_BAG_L2'],
#   'CatBoost_r9_BAG_L2': ['CatBoost_r9_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'KNeighborsUnif_BAG_L1': 0.03001093864440918,
#   'KNeighborsDist_BAG_L1': 0.03298354148864746,
#   'LightGBMXT_BAG_L1': 9.525662422180176,
#   'LightGBM_BAG_L1': 10.707069873809814,
#   'RandomForestGini_BAG_L1': 6.041172981262207,
#   'RandomForestEntr_BAG_L1': 6.961488246917725,
#   'CatBoost_BAG_L1': 175.06795573234558,
#   'ExtraTreesGini_BAG_L1': 2.1376636028289795,
#   'ExtraTreesEntr_BAG_L1': 2.1150009632110596,
#   'NeuralNetFastAI_BAG_L1': 297.0557312965393,
#   'XGBoost_BAG_L1': 12.478534698486328,
#   'NeuralNetTorch_BAG_L1': 266.30008602142334,
#   'LightGBMLarge_BAG_L1': 18.219497680664062,
#   'CatBoost_r177_BAG_L1': 28.312994956970215,
#   'NeuralNetTorch_r79_BAG_L1': 442.64947032928467,
#   'LightGBM_r131_BAG_L1': 22.003093719482422,
#   'NeuralNetFastAI_r191_BAG_L1': 742.8023841381073,
#   'CatBoost_r9_BAG_L1': 277.82654094696045,
#   'LightGBM_r96_BAG_L1': 29.609270334243774,
#   'NeuralNetTorch_r22_BAG_L1': 653.7668833732605,
#   'XGBoost_r33_BAG_L1': 24.51795721054077,
#   'ExtraTrees_r42_BAG_L1': 3.760165214538574,
#   'CatBoost_r137_BAG_L1': 214.47674012184143,
#   'NeuralNetFastAI_r102_BAG_L1': 79.91365313529968,
#   'CatBoost_r13_BAG_L1': 114.33668971061707,
#   'RandomForest_r195_BAG_L1': 22.260262727737427,
#   'LightGBM_r188_BAG_L1': 15.68030333518982,
#   'NeuralNetFastAI_r145_BAG_L1': 57.19690227508545,
#   'XGBoost_r89_BAG_L1': 4.477987766265869,
#   'WeightedEnsemble_L2': 40.67175507545471,
#   'LightGBMXT_BAG_L2': 12.600423336029053,
#   'LightGBM_BAG_L2': 13.138106107711792,
#   'RandomForestGini_BAG_L2': 15.408487319946289,
#   'RandomForestEntr_BAG_L2': 16.87116312980652,
#   'CatBoost_BAG_L2': 122.579838514328,
#   'ExtraTreesGini_BAG_L2': 2.854063034057617,
#   'ExtraTreesEntr_BAG_L2': 2.873936176300049,
#   'NeuralNetFastAI_BAG_L2': 294.45903515815735,
#   'XGBoost_BAG_L2': 12.702172994613647,
#   'NeuralNetTorch_BAG_L2': 270.14880895614624,
#   'LightGBMLarge_BAG_L2': 26.726049423217773,
#   'CatBoost_r177_BAG_L2': 31.34627056121826,
#   'NeuralNetTorch_r79_BAG_L2': 285.1822021007538,
#   'LightGBM_r131_BAG_L2': 24.29473567008972,
#   'NeuralNetFastAI_r191_BAG_L2': 553.6179928779602,
#   'CatBoost_r9_BAG_L2': 38.82844543457031,
#   'WeightedEnsemble_L3': 40.82855725288391},
#  'model_pred_times': {'KNeighborsUnif_BAG_L1': 0.7599921226501465,
#   'KNeighborsDist_BAG_L1': 0.726818323135376,
#   'LightGBMXT_BAG_L1': 0.1099846363067627,
#   'LightGBM_BAG_L1': 0.11795830726623535,
#   'RandomForestGini_BAG_L1': 1.3781745433807373,
#   'RandomForestEntr_BAG_L1': 1.3540372848510742,
#   'CatBoost_BAG_L1': 0.07951712608337402,
#   'ExtraTreesGini_BAG_L1': 1.540982961654663,
#   'ExtraTreesEntr_BAG_L1': 1.520993709564209,
#   'NeuralNetFastAI_BAG_L1': 0.5929965972900391,
#   'XGBoost_BAG_L1': 0.14800477027893066,
#   'NeuralNetTorch_BAG_L1': 0.3870089054107666,
#   'LightGBMLarge_BAG_L1': 0.1479940414428711,
#   'CatBoost_r177_BAG_L1': 0.07197833061218262,
#   'NeuralNetTorch_r79_BAG_L1': 0.5060017108917236,
#   'LightGBM_r131_BAG_L1': 0.20399188995361328,
#   'NeuralNetFastAI_r191_BAG_L1': 0.856971025466919,
#   'CatBoost_r9_BAG_L1': 0.09804105758666992,
#   'LightGBM_r96_BAG_L1': 0.2339944839477539,
#   'NeuralNetTorch_r22_BAG_L1': 0.5900142192840576,
#   'XGBoost_r33_BAG_L1': 0.18801331520080566,
#   'ExtraTrees_r42_BAG_L1': 1.4348137378692627,
#   'CatBoost_r137_BAG_L1': 0.07899093627929688,
#   'NeuralNetFastAI_r102_BAG_L1': 0.22199702262878418,
#   'CatBoost_r13_BAG_L1': 0.07900404930114746,
#   'RandomForest_r195_BAG_L1': 1.3738312721252441,
#   'LightGBM_r188_BAG_L1': 0.14595699310302734,
#   'NeuralNetFastAI_r145_BAG_L1': 1.183943748474121,
#   'XGBoost_r89_BAG_L1': 0.14700078964233398,
#   'WeightedEnsemble_L2': 0.08400249481201172,
#   'LightGBMXT_BAG_L2': 0.12894511222839355,
#   'LightGBM_BAG_L2': 0.12297773361206055,
#   'RandomForestGini_BAG_L2': 1.726269245147705,
#   'RandomForestEntr_BAG_L2': 1.68038010597229,
#   'CatBoost_BAG_L2': 0.09002566337585449,
#   'ExtraTreesGini_BAG_L2': 1.8088326454162598,
#   'ExtraTreesEntr_BAG_L2': 1.790750503540039,
#   'NeuralNetFastAI_BAG_L2': 0.6442005634307861,
#   'XGBoost_BAG_L2': 0.2200016975402832,
#   'NeuralNetTorch_BAG_L2': 0.7540032863616943,
#   'LightGBMLarge_BAG_L2': 0.16101455688476562,
#   'CatBoost_r177_BAG_L2': 0.08697628974914551,
#   'NeuralNetTorch_r79_BAG_L2': 0.8729956150054932,
#   'LightGBM_r131_BAG_L2': 0.1910240650177002,
#   'NeuralNetFastAI_r191_BAG_L2': 0.8853974342346191,
#   'CatBoost_r9_BAG_L2': 0.10798287391662598,
#   'WeightedEnsemble_L3': 0.0839991569519043},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'num_classes': 2,
#  'model_hyperparams': {'KNeighborsUnif_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'KNeighborsDist_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r96_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r22_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r33_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTrees_r42_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_r137_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r102_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r13_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForest_r195_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'LightGBM_r188_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r145_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_r89_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'RandomForestEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesGini_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'ExtraTreesEntr_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'NeuralNetFastAI_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r177_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_r79_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_r131_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetFastAI_r191_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'CatBoost_r9_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                           model  score_val  eval_metric  pred_time_val  \
#  0     NeuralNetTorch_r79_BAG_L2   0.187523  bank_profit      17.152004
#  1           WeightedEnsemble_L3   0.187523  bank_profit      17.236003
#  2         NeuralNetTorch_BAG_L2   0.186627  bank_profit      17.033011
#  3           WeightedEnsemble_L2   0.183815  bank_profit       1.567027
#  4     NeuralNetTorch_r79_BAG_L1   0.183759  bank_profit       0.506002
#  5     NeuralNetTorch_r22_BAG_L1   0.182422  bank_profit       0.590014
#  6         NeuralNetTorch_BAG_L1   0.181562  bank_profit       0.387009
#  7        NeuralNetFastAI_BAG_L2   0.177026  bank_profit      16.923208
#  8                XGBoost_BAG_L2   0.176568  bank_profit      16.499010
#  9               LightGBM_BAG_L2   0.176529  bank_profit      16.401986
#  10        ExtraTreesGini_BAG_L2   0.176413  bank_profit      18.087841
#  11              LightGBM_BAG_L1   0.176243  bank_profit       0.117958
#  12              CatBoost_BAG_L2   0.176201  bank_profit      16.369034
#  13        ExtraTreesEntr_BAG_L2   0.176193  bank_profit      18.069758
#  14         LightGBMLarge_BAG_L2   0.176121  bank_profit      16.440022
#  15      RandomForestGini_BAG_L2   0.176119  bank_profit      18.005277
#  16      RandomForestEntr_BAG_L2   0.176112  bank_profit      17.959388
#  17         LightGBM_r131_BAG_L2   0.176066  bank_profit      16.470032
#  18               XGBoost_BAG_L1   0.175847  bank_profit       0.148005
#  19            LightGBMXT_BAG_L2   0.175836  bank_profit      16.407953
#  20         CatBoost_r177_BAG_L2   0.175646  bank_profit      16.365984
#  21         LightGBMLarge_BAG_L1   0.175576  bank_profit       0.147994
#  22        ExtraTrees_r42_BAG_L1   0.175354  bank_profit       1.434814
#  23            LightGBMXT_BAG_L1   0.175325  bank_profit       0.109985
#  24  NeuralNetFastAI_r191_BAG_L2   0.175305  bank_profit      17.164405
#  25           CatBoost_r9_BAG_L2   0.174892  bank_profit      16.386991
#  26         LightGBM_r131_BAG_L1   0.174757  bank_profit       0.203992
#  27              CatBoost_BAG_L1   0.174616  bank_profit       0.079517
#  28         CatBoost_r177_BAG_L1   0.174574  bank_profit       0.071978
#  29      RandomForestGini_BAG_L1   0.174516  bank_profit       1.378175
#  30        ExtraTreesGini_BAG_L1   0.174485  bank_profit       1.540983
#  31           CatBoost_r9_BAG_L1   0.174444  bank_profit       0.098041
#  32           XGBoost_r33_BAG_L1   0.174416  bank_profit       0.188013
#  33     RandomForest_r195_BAG_L1   0.174391  bank_profit       1.373831
#  34          LightGBM_r96_BAG_L1   0.174362  bank_profit       0.233994
#  35         LightGBM_r188_BAG_L1   0.174349  bank_profit       0.145957
#  36           XGBoost_r89_BAG_L1   0.174250  bank_profit       0.147001
#  37      RandomForestEntr_BAG_L1   0.174233  bank_profit       1.354037
#  38         CatBoost_r137_BAG_L1   0.174157  bank_profit       0.078991
#  39          CatBoost_r13_BAG_L1   0.173803  bank_profit       0.079004
#  40  NeuralNetFastAI_r145_BAG_L1   0.173750  bank_profit       1.183944
#  41  NeuralNetFastAI_r102_BAG_L1   0.173596  bank_profit       0.221997
#  42        ExtraTreesEntr_BAG_L1   0.173448  bank_profit       1.520994
#  43       NeuralNetFastAI_BAG_L1   0.171826  bank_profit       0.592997
#  44  NeuralNetFastAI_r191_BAG_L1   0.171244  bank_profit       0.856971
#  45        KNeighborsDist_BAG_L1   0.133258  bank_profit       0.726818
#  46        KNeighborsUnif_BAG_L1   0.132437  bank_profit       0.759992
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   3825.446359                0.872996         285.182202            2
#  1   3866.274917                0.083999          40.828557            3
#  2   3810.412966                0.754003         270.148809            2
#  3   1403.388195                0.084002          40.671755            2
#  4    442.649470                0.506002         442.649470            1
#  5    653.766883                0.590014         653.766883            1
#  6    266.300086                0.387009         266.300086            1
#  7   3834.723192                0.644201         294.459035            2
#  8   3552.966330                0.220002          12.702173            2
#  9   3553.402263                0.122978          13.138106            2
#  10  3543.118220                1.808833           2.854063            2
#  11    10.707070                0.117958          10.707070            1
#  12  3662.843996                0.090026         122.579839            2
#  13  3543.138093                1.790751           2.873936            2
#  14  3566.990207                0.161015          26.726049            2
#  15  3555.672645                1.726269          15.408487            2
#  16  3557.135320                1.680380          16.871163            2
#  17  3564.558893                0.191024          24.294736            2
#  18    12.478535                0.148005          12.478535            1
#  19  3552.864581                0.128945          12.600423            2
#  20  3571.610428                0.086976          31.346271            2
#  21    18.219498                0.147994          18.219498            1
#  22     3.760165                1.434814           3.760165            1
#  23     9.525662                0.109985           9.525662            1
#  24  4093.882150                0.885397         553.617993            2
#  25  3579.092603                0.107983          38.828445            2
#  26    22.003094                0.203992          22.003094            1
#  27   175.067956                0.079517         175.067956            1
#  28    28.312995                0.071978          28.312995            1
#  29     6.041173                1.378175           6.041173            1
#  30     2.137664                1.540983           2.137664            1
#  31   277.826541                0.098041         277.826541            1
#  32    24.517957                0.188013          24.517957            1
#  33    22.260263                1.373831          22.260263            1
#  34    29.609270                0.233994          29.609270            1
#  35    15.680303                0.145957          15.680303            1
#  36     4.477988                0.147001           4.477988            1
#  37     6.961488                1.354037           6.961488            1
#  38   214.476740                0.078991         214.476740            1
#  39   114.336690                0.079004         114.336690            1
#  40    57.196902                1.183944          57.196902            1
#  41    79.913653                0.221997          79.913653            1
#  42     2.115001                1.520994           2.115001            1
#  43   297.055731                0.592997         297.055731            1
#  44   742.802384                0.856971         742.802384            1
#  45     0.032984                0.726818           0.032984            1
#  46     0.030011                0.759992           0.030011            1
#
#      can_infer  fit_order
#  0        True         43
#  1        True         47
#  2        True         40
#  3        True         30
#  4        True         15
#  5        True         20
#  6        True         12
#  7        True         38
#  8        True         39
#  9        True         32
#  10       True         36
#  11       True          4
#  12       True         35
#  13       True         37
#  14       True         41
#  15       True         33
#  16       True         34
#  17       True         44
#  18       True         11
#  19       True         31
#  20       True         42
#  21       True         13
#  22       True         22
#  23       True          3
#  24       True         45
#  25       True         46
#  26       True         16
#  27       True          7
#  28       True         14
#  29       True          5
#  30       True          8
#  31       True         18
#  32       True         21
#  33       True         26
#  34       True         19
#  35       True         27
#  36       True         29
#  37       True          6
#  38       True         23
#  39       True         25
#  40       True         28
#  41       True         24
#  42       True          9
#  43       True         10
#  44       True         17
#  45       True          2
#  46       True          1  }

# %%
display(predictor_ag.feature_importance(df))
# Out:
# Computing feature importance via permutation shuffling for 23 features using 5000 rows with 5 shuffle sets...
# 	1574.37s	= Expected runtime (314.87s per shuffle set)
# 	925.6s	= Actual runtime (Completed 5 of 5 shuffle sets)
#            importance    stddev   p_value  n  p99_high   p99_low
# PAY_0        0.040344  0.002796  0.000003  5  0.046101  0.034588
# LIMIT_BAL    0.014924  0.001387  0.000009  5  0.017780  0.012067
# BILL_AMT1    0.011954  0.002035  0.000097  5  0.016144  0.007765
# PAY_AMT1     0.010478  0.001546  0.000055  5  0.013661  0.007295
# PAY_2        0.009419  0.001599  0.000096  5  0.012712  0.006127
# PAY_AMT2     0.009379  0.002343  0.000431  5  0.014203  0.004554
# PAY_AMT3     0.009178  0.001892  0.000205  5  0.013074  0.005282
# PAY_3        0.008580  0.001125  0.000035  5  0.010897  0.006263
# PAY_AMT4     0.008247  0.001410  0.000099  5  0.011150  0.005344
# BILL_AMT2    0.008206  0.001676  0.000198  5  0.011656  0.004756
# BILL_AMT6    0.008008  0.001442  0.000121  5  0.010977  0.005039
# BILL_AMT5    0.007830  0.001046  0.000037  5  0.009984  0.005676
# BILL_AMT3    0.007595  0.002050  0.000579  5  0.011815  0.003375
# PAY_AMT6     0.007305  0.001319  0.000122  5  0.010021  0.004588
# PAY_4        0.006951  0.000793  0.000020  5  0.008584  0.005318
# PAY_5        0.006944  0.000705  0.000013  5  0.008395  0.005493
# AGE          0.006841  0.000797  0.000022  5  0.008482  0.005199
# PAY_AMT5     0.006751  0.001386  0.000202  5  0.009605  0.003898
# PAY_6        0.006681  0.000733  0.000017  5  0.008190  0.005171
# BILL_AMT4    0.005590  0.001043  0.000139  5  0.007737  0.003444
# EDUCATION    0.004543  0.000841  0.000135  5  0.006275  0.002812
# MARRIAGE     0.004033  0.000783  0.000162  5  0.005645  0.002422
# SEX          0.003377  0.000946  0.000668  5  0.005326  0.001429
